# %%
# %pylab inline
data = loadtxt('data.dat')

data = array(data)

print shape(data)

plot (data[0,:],data[1,:])
plot (data[0,:],data[600,:])
# Out:
# Populating the interactive namespace from numpy and matplotlib
# (1002, 1000)
